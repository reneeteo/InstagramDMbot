# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
import numpy as np

# %% [markdown]
# Send DM automatically (only for currently followed users).
# 1. log in
# 2. find user
# 3. go to dm url
# 4. click not now for the pop up that appears
# 5. attach image (sends automatically after attachment)
# 6. type message and sends
# 7. iterates through a list of users

# %%
def dmer(lst_usernames):
    
    browser = webdriver.Chrome()
    browser.get('https://www.instagram.com/accounts/login/')

    time.sleep(2)

    usrname_bar = browser.find_element_by_name('username')  # Find the username bar
    passwrd_bar = browser.find_element_by_name('password')  # Find the password bar

    username = 'xx'  # Enter your username here
    password = 'xx'  # Enter your password here


    usrname_bar.send_keys(username)
    passwrd_bar.send_keys(password + Keys.ENTER)
    
    print("Logged in.")

    time.sleep(5)
    
    for i in range(len(lst_usernames)):
        
        print(lst_usernames[i])
        
        print("Finding user.")
        
        browser.get('https://www.instagram.com/' + lst_usernames[i])

        browser.find_element_by_xpath('//button[text()="Message"]').click()

        time.sleep(5)
        
        if i == 0:
            notNow2 = browser.find_element_by_xpath('//button[text() = "Not Now"]')
            print(notNow2)
            
            if (notNow2.text == 'Not Now'):
                notNow2.click()
                time.sleep(2)
            else:
                print("NIL")
                
            print("In the DMs.")
 
            print("Attaching image.")
    
            img = browser.find_element_by_xpath('//button[@class="wpO6b "]/*[name()="svg"][@aria-label="Add Photo or Video"]').click()
            time.sleep(3)
            img = browser.find_element_by_xpath("//input[@type='file']")
            img.send_keys(r"C:\Users\xx") # Change path to image
            
            print("Attached.")
             
            txt_box = browser.find_element_by_tag_name('textarea')
            
            print("Typing.")
            
            msg1 = "test"
            msg2 = "test"
            txt_box.send_keys(msg1)  # Customize your message
            txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
            txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
            txt_box.send_keys(msg2)  # Customize your message
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(msg3)  # Customize your message
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(msg4)  # Customize your message
            
            
            print("Typed.")

            time.sleep(2)

            snd_btn = browser.find_element_by_xpath('//button[text() = "Send"]')
            snd_btn.click()
            
            print("Sent.")

            time.sleep(4)

        elif i!=0:
            
            print("In the DMs.")
            
#             print("Attaching image.")
            
#             img = browser.find_element_by_xpath('//button[@class="wpO6b "]/*[name()="svg"][@aria-label="Add Photo or Video"]').click()
#             time.sleep(3)
#             img = browser.find_element_by_xpath("//input[@type='file']")
#             img.send_keys(r"C:\Users\xx") # Change path to image
            
#             print("Attached.")
            
            txt_box = browser.find_element_by_tag_name('textarea')
            
            print("Typing.")

            msg1 = "Hi there, I am Renee from Sports Club, do you mind helping us repost our giveaway? Feel free to take part in it as well! Thank you!"
            msg2 = "https://www.instagram.com/p/CDO2BNHFVbQ/"
            txt_box.send_keys(msg1)  # Customize your message
            txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
            txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
            txt_box.send_keys(msg2)  # Customize your message
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(msg3)  # Customize your message
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(Keys.SHIFT, Keys.ENTER) # Create paragraph
#             txt_box.send_keys(msg4)  # Customize your message

            print("Typed.")

            time.sleep(2)

            snd_btn = browser.find_element_by_xpath('//button[text() = "Send"]')
            snd_btn.click()
            
            print("Sent.")

            time.sleep(2)
    browser.close()
            
    return ("Done all.")

# %% [markdown]
# Automatically follow users if not yet followed.

# %%
def followWithUsername(lst_usernames):
    browser = webdriver.Chrome()
    browser.get('https://www.instagram.com/accounts/login/')

    time.sleep(2)

    usrname_bar = browser.find_element_by_name('username')  # Find the username bar
    passwrd_bar = browser.find_element_by_name('password')  # Find the password bar

    username = 'xx'  # Enter your username here
    password = 'xx'  # Enter your password here

    usrname_bar.send_keys(username)
    passwrd_bar.send_keys(password + Keys.ENTER)
    
    print("Logged in.")
    
    time.sleep(3)
    
    for i in range(len(lst_usernames)):
        print("Finding " + lst_usernames[i])
        browser.get('https://www.instagram.com/' + lst_usernames[i] + '/')
        time.sleep(2)
        followButton = browser.find_element_by_xpath('//button')
        if (followButton.text != 'Following'):
            followButton.click()
            print("Followed.")
            time.sleep(3)
        else:
            print("You are already following this user.")
        time.sleep(5)
    browser.close()

# %% [markdown]
# Send DMs chunk by chunk to prevent detection of unusual activity

# %%
def chunks(l, n): 
    for i in range(0, len(l), n):  
        yield l[i:i + n] 
  
  
insta_list = list(chunks(insta_list, 10)) 
print (insta_list)

# %%
for i in range(len(insta_list)):
    followWithUsername(insta_list[i])
    time.sleep(300)

# %%
for i in insta_list:
    dmer(i)
